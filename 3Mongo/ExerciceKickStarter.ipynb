# %% [markdown]
# #  Consignes
#
# ## Description
#
# Ouvrir le fichier ks-projects-201801.csv, il recense environ 100 000 projets KickStarter. Intégrer les données directement avec L'API Python dans une base de données Mongo.
#
# Il conviendra de bien spécifier manuellement l'ID du document. Pensez aussi à bien formatter le type des données pour profiter des méthodes implémentées par Mongo. L'ensemble de données n'est pas forcément nécessaire, c'est à vous de créer votre modèle de données.
#
# ## Questions
#
# - 1) Récupérer les 5 projets ayant reçu le plus de promesse de dons.
# - 2) Compter le nombre de projets ayant atteint leur but.
# - 3) Compter le nombre de projets pour chaque catégorie.
# - 4) Compter le nombre de projets français ayant été instanciés avant 2016.
# - 5) Récupérer les projets américains ayant demandé plus de 200 000 dollars.
# - 6) Compter le nombre de projet ayant "Sport" dans leur nom

# %%
# !cat /etc/lsb-release
# Out:
# cat: /etc/lsb-release: No such file or directory

# %%
import pandas as pd
import pymongo

# %%
client = pymongo.MongoClient()
database = client['exercices']
collection = database['kickstarter']

# %%
df_ks = pd.read_csv("./data/ks-projects-201801-sample.csv")
df_ks.head(30)
# Out:
# /var/folders/tj/jms4ydz11w55nh0ksfvk1cvh0000gn/T/ipykernel_45370/2303492172.py:1: DtypeWarning: Columns (6,8,10,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ks = pd.read_csv("./data/ks-projects-201801-sample.csv")
#             ID                                               name  \
# 0    872782264    Scott Cooper's Solo CD "A Leg Trick" (Canceled)
# 1   1326492673                                    Ohceola jewelry
# 2   1688410639  Sluff Off & Harald: Two latest EGGs are Classi...
# 3    156812982  SketchPlanner: Create and Plan- all in one bea...
# 4   1835968190    Proven sales with custom motorcycle accessories
# 5   1771789139                                   Room For Growth!
# 6   1301627822          Build a mini Udemy with Laravel and Vuejs
# 7    881336601                                         Applitizer
# 8   1669374237  Help I Am Wolves fund their first album "ABCD"...
# ...

# %% [markdown]
# Ce warning intervient lorsque pandas n'arrive pas à inférer le type de données. Il est sympa il précise les colones 6,8,10,12.

# %%
df_ks.columns[[6,8,10,12]]
# Out:
# Index(['goal', 'pledged', 'backers', 'usd pledged'], dtype='object')

# %% [markdown]
# ## Question 0

# %% [markdown]
# ### Netoyer les données

# %%
df_ks['goal'] = pd.to_numeric(df_ks['goal'], errors='coerce')
df_ks = df_ks.dropna(subset=['goal'])
df_ks['pledged'] = pd.to_numeric(df_ks['pledged'], errors='coerce')
df_ks = df_ks.dropna(subset=['pledged'])
df_ks['usd pledged'] = pd.to_numeric(df_ks['usd pledged'], errors='coerce')
df_ks = df_ks.dropna(subset=['usd pledged'])
df_ks['backers'] = pd.to_numeric(df_ks['backers'], errors='coerce')
df_ks = df_ks.dropna(subset=['backers'])



df_ks['pledged']=df_ks['pledged'].astype('float')
df_ks['goal']=df_ks['goal'].astype('float')
df_ks['backers']=df_ks['backers'].astype('int')

df_ks['deadline'] = pd.to_datetime(df_ks['deadline'])
df_ks['launched'] = pd.to_datetime(df_ks['launched'])

df_ks['usd pledged']=df_ks['usd pledged'].astype('float')
#df_ks= pd.fillna(0,inplace= True )

#df_ks.head(30)
# Out:
#             ID                                               name  \
# 0    872782264    Scott Cooper's Solo CD "A Leg Trick" (Canceled)
# 1   1326492673                                    Ohceola jewelry
# 2   1688410639  Sluff Off & Harald: Two latest EGGs are Classi...
# 3    156812982  SketchPlanner: Create and Plan- all in one bea...
# 4   1835968190    Proven sales with custom motorcycle accessories
# 5   1771789139                                   Room For Growth!
# 6   1301627822          Build a mini Udemy with Laravel and Vuejs
# 7    881336601                                         Applitizer
# 8   1669374237  Help I Am Wolves fund their first album "ABCD"...
# 9    556821416        Eco  Bamboo Underwear funding....GOT WOOD ?
# 10   160394496                         SHAKTI: The Power of Woman
# 11  1248488072                                   Coast to Coaster
# 12   895565490                   Frostbite Gaming - Minecraft HUB
# ...

# %% [markdown]
# ### Importer les données

# %% [markdown]
# ## Question 1

# %%
Mostpledged= df_ks.nlargest(5,'pledged')
Mostpledged
# Out:
#                 ID                                               name  \
# 76581    342886736  COOLEST COOLER: 21st Century Cooler that's Act...
# 99870   2103598555             Pebble 2, Time 2 + All-New Pebble Core
# 79708   2111201788  Expect the Unexpected. digiFilmï¿½ Camera by Y...
# 113465  1033978702             OUYA: A New Kind of Video Game Console
# 144112   450099426             The Everyday Backpack, Tote, and Sling
#
#                category main_category currency   deadline       goal  \
# 76581    Product Design        Design      USD 2014-08-30    50000.0
# 99870    Product Design        Design      USD 2016-06-30  1000000.0
# 79708    Product Design        Design      HKD 2017-11-19   800000.0
# 113465  Gaming Hardware         Games      USD 2012-08-09   950000.0
# 144112   Product Design        Design      USD 2016-09-10   500000.0
#
#                   launched      pledged       state  backers country  \
# ...

# %% [markdown]
# ## Question 2

# %%
Nb= (df_ks['state']=='successful').sum()
Nb
# Out:
# 52998

# %% [markdown]
# ## Question 3

# %% [markdown]
# ## Question 4

# %% [markdown]
# ## Question 5

# %% [markdown]
# ## Question 6
